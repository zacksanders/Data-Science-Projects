# %% [markdown]
# # Curve Fitting of COVID Data
#
# Here, we will fit the data that we organized in data.ipynb to two curves: a simple Gaussian curve, and the Gompertz curve.
#
# Early in the pandemic, many scientific publications used these curves to predict the progression of COVID-19. They turned out to be wildly inaccurate. These curves assume a natural spread without taking into account social distancing or mandated lockdowns.
#
# As restrictions changed, the data stopped following these clean trends and I decided to stop doing this project. The fact is that it's impossible to predict when COVID will end because it is dependent on a plethora of sensitive factors.
#
# Just for the sake of demonstration, let's look at some data that did have a clean trend: Thailand.

# %%
import pandas as pd
import numpy as np
from scipy.special import expit
from sklearn.svm import SVR
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
run -i 'data.ipynb'
# Out:
# 6/4/20    3101
# Name: Thailand, dtype: object
# [[128]]

# %%
x = np.array(x)

def gaussian(X, a, b, c):
    return a * np.exp(-0.5 * ((X-b)/c)**2)
def gompertz(x,a,b,c):
    return a*-b*-c*expit(-b*expit(-c*x))*expit(-c*x)


xdata = x
ydata = av
plt.plot(xdata, ydata, 'b-', label='data')

popt, pcov = curve_fit(gaussian, xdata, ydata)
popt 
plt.plot(xdata, gaussian(xdata, *popt), 'r-', label='gaussian fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt))

popt, pcov = curve_fit(gompertz, xdata, ydata)
popt 
plt.plot(xdata, gompertz(xdata, *popt), 'g-', label='gompertz fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt))

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# What we can gleam from this is that Thailand was consistent enough in handling COVID that their data had a clean trend, mimicing a natural progression of a disease. The Gompertz curve seemed to have a better fit than the simple Gaussian.
#
# If this was the case for other countries, then we could repeat this process for every country that peaked, and make a prediction for other countries in earlier stages. But we can't, so we won't.
